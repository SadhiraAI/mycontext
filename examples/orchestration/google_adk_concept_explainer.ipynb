# %% [markdown]
# # Google Agent Development Kit (ADK) + mycontext ConceptExplainer
#
# Simple integration: **ConceptExplainer** template as ADK agent instruction → verify templates work.
#
# **Template:** `concept_explainer` — explains complex concepts with layered depth
#
# **Prerequisites:**
# ```bash
# pip install "mycontext-ai[google]" google-adk
# ```
# Set `GOOGLE_API_KEY` (Gemini API key from Google AI Studio).

# %%
# !pip install "mycontext-ai[google]" google-adk

# %%
import os

os.environ['OPENAI_API_KEY'] = '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'
os.environ['ANTHROPIC_API_KEY'] = 'sk-ant-...'
os.environ['GOOGLE_API_KEY'] = 'AIzaSyBGFwXNLmTYPnRztxU5HCc1Es9KxAMU8r4'

# %%
from mycontext.intelligence import get_pattern_class

ConceptExplainer = get_pattern_class("concept_explainer")
concept = "quantum entanglement"
audience = "high school students"

ctx = ConceptExplainer().build_context(
    concept=concept,
    audience=audience,
    depth="comprehensive",
    context=""
)
instruction = ctx.assemble()
print("Context built. Instruction length:", len(instruction), "chars")
# Out:
# Context built. Instruction length: 4142 chars

# %%
try:
    from google.adk.runners import InMemoryRunner

    from mycontext.integrations import GoogleADKHelper
except ImportError:
    raise ImportError("pip install mycontext-ai google-adk")

agent = GoogleADKHelper.create_agent(
    ctx,
    name="concept_explainer",
    model="gemini-2.5-flash-lite",
    description="Explains complex concepts clearly with layered depth",
)

runner = InMemoryRunner(agent=agent)
result = await runner.run_debug(f"Explain {concept} for {audience}")
print(result)
print("\n--- Template works with Google ADK ---")
# Out:
#  ### Created new session: debug_session_id
#
# User > Explain quantum entanglement for high school students
# concept_explainer > Let's dive into one of the most mind-bending ideas in science: **quantum entanglement**. It sounds like science fiction, but it's a very real phenomenon that's shaping the future of technology!
#
# ## 1. THE BIG PICTURE (Why This Matters)
#
# **Real-World Relevance**:
# Why should you care about quantum entanglement? Because it's not just a weird theoretical idea; it's the bedrock of incredible new technologies.
# *   **Super-Secure Communication:** Entanglement can be used to create communication systems that are virtually unhackable. Imagine sending messages where any attempt to eavesdrop instantly alerts both sender and receiver. This is the basis of **quantum cryptography**.
# ...
